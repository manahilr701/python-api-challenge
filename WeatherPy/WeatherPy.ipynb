# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san antonio de pale
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | mantua
# Processing Record 7 of Set 1 | lasem
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | hobyo
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | kasumkent
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | bilibino
# Processing Record 14 of Set 1 | vilyuchinsk
# Processing Record 15 of Set 1 | happy valley-goose bay
# Processing Record 16 of Set 1 | agat village
# Processing Record 17 of Set 1 | uturoa
# Processing Record 18 of Set 1 | la sarre
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | hengchun
# Processing Record 23 of Set 1 | serhetabat
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | isle of lewis
# City not found. Skipping...
# Processing Record 26 of Set 1 | mbanza kongo
# Processing Record 27 of Set 1 | santarem
# Processing Record 28 of Set 1 | abraham's bay
# City not found. Skipping...
# Processing Record 29 of Set 1 | blackmans bay
# Processing Record 30 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 31 of Set 1 | pathein
# Processing Record 32 of Set 1 | sikonge
# Processing Record 33 of Set 1 | invercargill
# Processing Record 34 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 35 of Set 1 | madugula
# Processing Record 36 of Set 1 | 'ain el melh
# Processing Record 37 of Set 1 | grytviken
# Processing Record 38 of Set 1 | greenwood
# Processing Record 39 of Set 1 | mahbubabad
# Processing Record 40 of Set 1 | saipan
# Processing Record 41 of Set 1 | west island
# Processing Record 42 of Set 1 | kirakira
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | fruita
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | howard springs
# Processing Record 47 of Set 1 | palmer
# Processing Record 48 of Set 1 | mil'kovo
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | alofi
# Processing Record 0 of Set 2 | bianzhuang
# Processing Record 1 of Set 2 | keflavik
# Processing Record 2 of Set 2 | pisco
# Processing Record 3 of Set 2 | lethem
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | margaret river
# Processing Record 6 of Set 2 | zima
# Processing Record 7 of Set 2 | phan rang-thap cham
# Processing Record 8 of Set 2 | ust-nera
# Processing Record 9 of Set 2 | port saint john's
# Processing Record 10 of Set 2 | tazovsky
# Processing Record 11 of Set 2 | churapcha
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | arkhangel'sk
# Processing Record 14 of Set 2 | chernyshevskiy
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | kapa'a
# Processing Record 17 of Set 2 | inarajan village
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | virginia beach
# Processing Record 20 of Set 2 | qaqortoq
# Processing Record 21 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 2 | sola
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | tangalle
# Processing Record 25 of Set 2 | dhidhdhoo
# Processing Record 26 of Set 2 | sofifi
# Processing Record 27 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | cusseta
# Processing Record 30 of Set 2 | edinburgh of the seven seas
# Processing Record 31 of Set 2 | ketchikan
# Processing Record 32 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 2 | tshabong
# Processing Record 34 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 35 of Set 2 | whitehorse
# Processing Record 36 of Set 2 | nova vicosa
# Processing Record 37 of Set 2 | ataq
# Processing Record 38 of Set 2 | lanark
# Processing Record 39 of Set 2 | dudinka
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | papatowai
# Processing Record 42 of Set 2 | karatau
# Processing Record 43 of Set 2 | palikir - national government center
# Processing Record 44 of Set 2 | le port
# Processing Record 45 of Set 2 | al qaryatayn
# Processing Record 46 of Set 2 | kangaba
# Processing Record 47 of Set 2 | puerto armuelles
# Processing Record 48 of Set 2 | utete
# Processing Record 49 of Set 2 | awjilah
# Processing Record 0 of Set 3 | vorgashor
# Processing Record 1 of Set 3 | rongelap
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | newton
# Processing Record 4 of Set 3 | aykhal
# Processing Record 5 of Set 3 | aasiaat
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | chanasma
# Processing Record 8 of Set 3 | axim
# Processing Record 9 of Set 3 | anchorage
# Processing Record 10 of Set 3 | port mathurin
# Processing Record 11 of Set 3 | guangyuan
# Processing Record 12 of Set 3 | pacific grove
# Processing Record 13 of Set 3 | udachny
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | manokwari
# Processing Record 16 of Set 3 | ingeniero guillermo n. juarez
# Processing Record 17 of Set 3 | cururupu
# Processing Record 18 of Set 3 | ulsteinvik
# Processing Record 19 of Set 3 | vadso
# Processing Record 20 of Set 3 | birjand
# Processing Record 21 of Set 3 | olonkinbyen
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | homer
# Processing Record 24 of Set 3 | eyl
# Processing Record 25 of Set 3 | minas de marcona
# Processing Record 26 of Set 3 | wailua homesteads
# Processing Record 27 of Set 3 | egilsstadir
# Processing Record 28 of Set 3 | berezovyy
# Processing Record 29 of Set 3 | badger
# Processing Record 30 of Set 3 | la ligua
# Processing Record 31 of Set 3 | ljusdal
# Processing Record 32 of Set 3 | khandyga
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | conde
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | stanley
# Processing Record 37 of Set 3 | akureyri
# Processing Record 38 of Set 3 | maxixe
# Processing Record 39 of Set 3 | la'ie
# Processing Record 40 of Set 3 | xinqing
# Processing Record 41 of Set 3 | lata
# Processing Record 42 of Set 3 | frontera
# Processing Record 43 of Set 3 | kiruna
# Processing Record 44 of Set 3 | enewetak
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | floro
# Processing Record 47 of Set 3 | severodvinsk
# Processing Record 48 of Set 3 | tolanaro
# Processing Record 49 of Set 3 | georgetown
# Processing Record 0 of Set 4 | sant lluis
# Processing Record 1 of Set 4 | itamaraca
# Processing Record 2 of Set 4 | kokopo
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | uliastay
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | hotan
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | san andres
# Processing Record 10 of Set 4 | latakia
# Processing Record 11 of Set 4 | iskateley
# Processing Record 12 of Set 4 | carutapera
# Processing Record 13 of Set 4 | fale old settlement
# Processing Record 14 of Set 4 | yuxi
# Processing Record 15 of Set 4 | westport
# Processing Record 16 of Set 4 | boca suno
# Processing Record 17 of Set 4 | kenai
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | lihue
# Processing Record 20 of Set 4 | balaklava
# Processing Record 21 of Set 4 | miles city
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | ambalangoda
# Processing Record 24 of Set 4 | constantia
# Processing Record 25 of Set 4 | bikenibeu village
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | isabel segunda
# Processing Record 30 of Set 4 | ta`u
# Processing Record 31 of Set 4 | zaltan
# Processing Record 32 of Set 4 | shubarshi
# Processing Record 33 of Set 4 | pangody
# Processing Record 34 of Set 4 | svetlyy
# Processing Record 35 of Set 4 | rio grande
# Processing Record 36 of Set 4 | sinabang
# Processing Record 37 of Set 4 | san carlos
# Processing Record 38 of Set 4 | rabo de peixe
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | yuli
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | orapa
# Processing Record 44 of Set 4 | sri dungargarh
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | hawaiian paradise park
# Processing Record 47 of Set 4 | mana
# Processing Record 48 of Set 4 | lamas
# Processing Record 49 of Set 4 | yugorsk
# Processing Record 0 of Set 5 | luderitz
# Processing Record 1 of Set 5 | weno
# Processing Record 2 of Set 5 | al kharijah
# Processing Record 3 of Set 5 | klyuchi
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | crane
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | george town
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | saudarkrokur
# Processing Record 10 of Set 5 | chios
# Processing Record 11 of Set 5 | malvan
# Processing Record 12 of Set 5 | tsiombe
# Processing Record 13 of Set 5 | puerto colombia
# Processing Record 14 of Set 5 | grand falls-windsor
# Processing Record 15 of Set 5 | port alfred
# Processing Record 16 of Set 5 | la passe
# Processing Record 17 of Set 5 | ciudad melchor muzquiz
# Processing Record 18 of Set 5 | alice springs
# Processing Record 19 of Set 5 | suzun
# Processing Record 20 of Set 5 | mareeba
# Processing Record 21 of Set 5 | jogindarnagar
# Processing Record 22 of Set 5 | kapuskasing
# Processing Record 23 of Set 5 | embi
# Processing Record 24 of Set 5 | alotau
# Processing Record 25 of Set 5 | yaren
# Processing Record 26 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 5 | marsabit
# Processing Record 28 of Set 5 | ndelele
# Processing Record 29 of Set 5 | atafu village
# Processing Record 30 of Set 5 | papao
# Processing Record 31 of Set 5 | baidoa
# Processing Record 32 of Set 5 | isafjordur
# Processing Record 33 of Set 5 | tazacorte
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | colonia
# Processing Record 36 of Set 5 | inhambane
# Processing Record 37 of Set 5 | riobamba
# Processing Record 38 of Set 5 | tachilek
# City not found. Skipping...
# Processing Record 39 of Set 5 | krasnyy chikoy
# Processing Record 40 of Set 5 | vikhorevka
# Processing Record 41 of Set 5 | greenacres
# Processing Record 42 of Set 5 | edd
# Processing Record 43 of Set 5 | port isabel
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | tari
# Processing Record 46 of Set 5 | nichinan
# Processing Record 47 of Set 5 | almeirim
# Processing Record 48 of Set 5 | cascavel
# Processing Record 49 of Set 5 | mindelo
# Processing Record 0 of Set 6 | bamboo flat
# Processing Record 1 of Set 6 | wailea
# Processing Record 2 of Set 6 | kasongo-lunda
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | buckhannon
# Processing Record 5 of Set 6 | siwa oasis
# Processing Record 6 of Set 6 | chul'man
# Processing Record 7 of Set 6 | mojo
# Processing Record 8 of Set 6 | dobryanka
# Processing Record 9 of Set 6 | st. john's
# Processing Record 10 of Set 6 | utrik
# Processing Record 11 of Set 6 | itoman
# Processing Record 12 of Set 6 | tofol
# Processing Record 13 of Set 6 | remire-montjoly
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | prado
# Processing Record 16 of Set 6 | penzance
# Processing Record 17 of Set 6 | nicoya
# Processing Record 18 of Set 6 | sodra sandby
# Processing Record 19 of Set 6 | lamesa
# Processing Record 20 of Set 6 | mbandaka
# Processing Record 21 of Set 6 | masterton
# Processing Record 22 of Set 6 | college
# Processing Record 23 of Set 6 | padangsidempuan
# Processing Record 24 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 25 of Set 6 | nova sintra
# Processing Record 26 of Set 6 | igarka
# Processing Record 27 of Set 6 | san luis de la loma
# Processing Record 28 of Set 6 | tibanbang
# Processing Record 29 of Set 6 | fort bragg
# Processing Record 30 of Set 6 | arvayheer
# Processing Record 31 of Set 6 | uruana
# Processing Record 32 of Set 6 | jamestown
# Processing Record 33 of Set 6 | ulladulla
# Processing Record 34 of Set 6 | mahina
# Processing Record 35 of Set 6 | kimbe
# Processing Record 36 of Set 6 | kui buri
# Processing Record 37 of Set 6 | paita
# Processing Record 38 of Set 6 | nuuk
# Processing Record 39 of Set 6 | anadyr
# Processing Record 40 of Set 6 | jiujiang
# Processing Record 41 of Set 6 | horta
# Processing Record 42 of Set 6 | pedernales
# Processing Record 43 of Set 6 | villefranche-de-rouergue
# Processing Record 44 of Set 6 | carrizo springs
# Processing Record 45 of Set 6 | brandon
# Processing Record 46 of Set 6 | brigantine
# Processing Record 47 of Set 6 | kubinka
# Processing Record 48 of Set 6 | selfoss
# Processing Record 49 of Set 6 | puerto baquerizo moreno
# Processing Record 0 of Set 7 | vila franca do campo
# Processing Record 1 of Set 7 | polyarnyy
# Processing Record 2 of Set 7 | midvagur
# Processing Record 48 of Set 9 | port alberni
# Processing Record 49 of Set 9 | el granada
# Processing Record 0 of Set 10 | halifax
# Processing Record 1 of Set 10 | andergrove
# Processing Record 2 of Set 10 | novyy urgal
# Processing Record 3 of Set 10 | dembi dolo
# Processing Record 4 of Set 10 | baker city
# Processing Record 5 of Set 10 | gadzhiyevo
# Processing Record 6 of Set 10 | kabansk
# Processing Record 7 of Set 10 | gillette
# Processing Record 8 of Set 10 | gornozavodsk
# Processing Record 9 of Set 10 | arteche
# Processing Record 10 of Set 10 | candelaria
# Processing Record 11 of Set 10 | coron
# Processing Record 12 of Set 10 | kodinsk
# Processing Record 13 of Set 10 | tonghae
# Processing Record 14 of Set 10 | obanazawa
# Processing Record 15 of Set 10 | labasa
# Processing Record 16 of Set 10 | yallahs
# Processing Record 17 of Set 10 | anatuya
# Processing Record 18 of Set 10 | male
# Processing Record 19 of Set 10 | pasuquin
# Processing Record 20 of Set 10 | acarau
# Processing Record 21 of Set 10 | lagos
# Processing Record 22 of Set 10 | tindouf
# Processing Record 23 of Set 10 | kostomuksha
# Processing Record 24 of Set 10 | carandai
# Processing Record 25 of Set 10 | xingcheng
# Processing Record 26 of Set 10 | puerto san jose
# Processing Record 27 of Set 10 | praia da vitoria
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | ambodifotatra
# Processing Record 30 of Set 10 | moyale
# Processing Record 31 of Set 10 | robore
# Processing Record 32 of Set 10 | sinop
# Processing Record 33 of Set 10 | al ghayzah
# Processing Record 34 of Set 10 | tidjikja
# Processing Record 35 of Set 10 | clarkston heights-vineland
# Processing Record 36 of Set 10 | nahrin
# Processing Record 37 of Set 10 | piton saint-leu
# Processing Record 38 of Set 10 | port douglas
# Processing Record 39 of Set 10 | capitan bado
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | pangai
# Processing Record 42 of Set 10 | nytva
# Processing Record 43 of Set 10 | isangel
# Processing Record 44 of Set 10 | nago
# Processing Record 45 of Set 10 | kuragino
# Processing Record 46 of Set 10 | rokytne
# Processing Record 47 of Set 10 | minab
# Processing Record 48 of Set 10 | cole harbour
# Processing Record 49 of Set 10 | nabire
# Processing Record 0 of Set 11 | mili
# Processing Record 1 of Set 11 | muravlenko
# Processing Record 2 of Set 11 | yuzhno-kurilsk
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | dese
# Processing Record 5 of Set 11 | plastun
# Processing Record 6 of Set 11 | sirte
# Processing Record 7 of Set 11 | menongue
# Processing Record 8 of Set 11 | colotlan
# Processing Record 9 of Set 11 | zakamensk
# Processing Record 10 of Set 11 | kiiminki
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | bandar-e genaveh
# Processing Record 13 of Set 11 | laguna
# Processing Record 14 of Set 11 | trairi
# Processing Record 15 of Set 11 | skowhegan
# Processing Record 16 of Set 11 | namsos
# Processing Record 17 of Set 11 | terenos
# Processing Record 18 of Set 11 | shingu
# Processing Record 19 of Set 11 | kapit
# Processing Record 20 of Set 11 | jamalpur
# Processing Record 21 of Set 11 | 'izbat al burj
# City not found. Skipping...
# Processing Record 22 of Set 11 | newman
# Processing Record 23 of Set 11 | ocean shores
# Processing Record 24 of Set 11 | juneau
# Processing Record 25 of Set 11 | shanwei
# Processing Record 26 of Set 11 | popondetta
# Processing Record 27 of Set 11 | villa gesell
# Processing Record 28 of Set 11 | tanki leendert
# City not found. Skipping...
# Processing Record 29 of Set 11 | tralee
# Processing Record 30 of Set 11 | civitavecchia
# Processing Record 31 of Set 11 | dul'durga
# Processing Record 32 of Set 11 | greymouth
# Processing Record 33 of Set 11 | zeya
# Processing Record 34 of Set 11 | nanping
# Processing Record 35 of Set 11 | sao jose da coroa grande
# Processing Record 36 of Set 11 | brookings
# Processing Record 37 of Set 11 | bosansko grahovo
# Processing Record 38 of Set 11 | flying fish cove
# Processing Record 39 of Set 11 | bandon
# Processing Record 40 of Set 11 | mong cai
# City not found. Skipping...
# Processing Record 41 of Set 11 | wimpassing
# Processing Record 42 of Set 11 | amahai
# Processing Record 43 of Set 11 | bayganin
# Processing Record 44 of Set 11 | sarupathar
# Processing Record 45 of Set 11 | north bend
# Processing Record 46 of Set 11 | fort stockton
# Processing Record 47 of Set 11 | ballito
# Processing Record 48 of Set 11 | san pedro pochutla
# Processing Record 49 of Set 11 | miltenberg
# Processing Record 0 of Set 12 | kailua-kona
# Processing Record 1 of Set 12 | namie
# Processing Record 2 of Set 12 | mios
# Processing Record 3 of Set 12 | mobaye
# Processing Record 4 of Set 12 | qibray
# Processing Record 5 of Set 12 | harper
# Processing Record 6 of Set 12 | nikel
# Processing Record 7 of Set 12 | pirallahi
# Processing Record 8 of Set 12 | mamuju
# Processing Record 9 of Set 12 | quatre cocos
# Processing Record 10 of Set 12 | aral
# Processing Record 11 of Set 12 | isla del bosque
# Processing Record 12 of Set 12 | tambura
# Processing Record 13 of Set 12 | dilling
# Processing Record 14 of Set 12 | kasamwa
# Processing Record 15 of Set 12 | tawau
# Processing Record 16 of Set 12 | tezu
# Processing Record 17 of Set 12 | saint-jean-de-monts
# Processing Record 18 of Set 12 | gueltat zemmour
# City not found. Skipping...
# Processing Record 19 of Set 12 | kalispell
# Processing Record 20 of Set 12 | guercif
# Processing Record 21 of Set 12 | khovd
# Processing Record 22 of Set 12 | waddan
# Processing Record 23 of Set 12 | corinto
# Processing Record 24 of Set 12 | nyurba
# Processing Record 25 of Set 12 | nacogdoches
# Processing Record 26 of Set 12 | shagonar
# Processing Record 27 of Set 12 | taulaga
# Processing Record 28 of Set 12 | suva
# Processing Record 29 of Set 12 | west melbourne
# Processing Record 30 of Set 12 | ushtobe
# Processing Record 31 of Set 12 | forster
# Processing Record 32 of Set 12 | ola
# Processing Record 33 of Set 12 | walvis bay
# Processing Record 34 of Set 12 | nizhniy ingash
# Processing Record 35 of Set 12 | noosa heads
# Processing Record 36 of Set 12 | waingapu
# Processing Record 37 of Set 12 | regina
# Processing Record 38 of Set 12 | obo
# Processing Record 39 of Set 12 | vetluzhskiy
# Processing Record 40 of Set 12 | strugi-krasnyye
# Processing Record 41 of Set 12 | praia
# Processing Record 42 of Set 12 | swakopmund
# Processing Record 43 of Set 12 | waterloo
# Processing Record 44 of Set 12 | nishifukuma
# Processing Record 45 of Set 12 | caleta de carquin
# Processing Record 46 of Set 12 | kas
# Processing Record 47 of Set 12 | skovorodino
# Processing Record 48 of Set 12 | kingston
# Processing Record 49 of Set 12 | natal
# Processing Record 0 of Set 13 | noyabrsk
# Processing Record 1 of Set 13 | carrboro
# Processing Record 2 of Set 13 | kawthoung
# City not found. Skipping...
# Processing Record 3 of Set 13 | jinchang
# Processing Record 4 of Set 13 | yelizovo
# Processing Record 5 of Set 13 | betio village
# Processing Record 6 of Set 13 | eastham
# Processing Record 7 of Set 13 | mersing
# Processing Record 8 of Set 13 | priargunsk
# Processing Record 9 of Set 13 | buala
# Processing Record 10 of Set 13 | wakkanai
# Processing Record 11 of Set 13 | xinyuan
# Processing Record 12 of Set 13 | kalianget
# Processing Record 13 of Set 13 | hovd
# Processing Record 14 of Set 13 | takoradi
# Processing Record 15 of Set 13 | barro
# Processing Record 16 of Set 13 | usakos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  san antonio de pale  -1.4014    5.6325     22.08        75          99
# 1             waitangi -43.9535 -176.5597     10.56        84          53
# 2       ribeira grande  38.5167  -28.7000     24.87        92          18
# 3            adamstown -25.0660 -130.1015     19.04        71          17
# 4                tiksi  71.6872  128.8694     15.20        62         100
#
#    Wind Speed Country        Date
# 0        4.44      GQ  1722902905
# 1        2.68      NZ  1722902906
# 2        2.68      PT  1722902909
# 3        5.94      PN  1722902910
# 4        3.43      RU  1722902912

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        san antonio de pale  -1.4014    5.6325     22.08        75
# 1                   waitangi -43.9535 -176.5597     10.56        84
# 2             ribeira grande  38.5167  -28.7000     24.87        92
# 3                  adamstown -25.0660 -130.1015     19.04        71
# 4                      tiksi  71.6872  128.8694     15.20        62
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        4.44      GQ  1722902905
# 1                53        2.68      NZ  1722902906
# 2                18        2.68      PT  1722902909
# 3                17        5.94      PN  1722902910
# 4               100        3.43      RU  1722902912

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="k", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")


# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="k", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="k", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="k", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, xlabel, ylabel, save_path):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate regression values
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Plot scatter plot and regression line
    plt.figure(figsize=(10, 6))
    plt.scatter(x_values, y_values, edgecolors="k", alpha=0.75)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    
    # Save the figure
    plt.savefig(save_path)
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        ribeira grande  38.5167  -28.7000     24.87        92          18
# 4                 tiksi  71.6872  128.8694     15.20        62         100
# 5                mantua  45.1667   10.7833     25.61        83          20
# 7                bethel  41.3712  -73.4140     26.93        83          43
# 8                 hobyo   5.3505   48.5268     24.08        85          71
#
#          Wind Speed Country        Date
# City_ID
# 2              2.68      PT  1722902909
# 4              3.43      RU  1722902912
# 5              1.34      IT  1722902913
# 7              0.45      US  1722902915
# 8             11.19      SO  1722902916

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        san antonio de pale  -1.4014    5.6325     22.08        75
# 1                   waitangi -43.9535 -176.5597     10.56        84
# 3                  adamstown -25.0660 -130.1015     19.04        71
# 6                      lasem  -6.6922  111.4527     24.28        74
# 9          port-aux-francais -49.3500   70.2167      1.41        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        4.44      GQ  1722902905
# 1                53        2.68      NZ  1722902906
# 3                17        5.94      PN  1722902910
# 6               100        2.92      ID  1722902914
# 9                86       10.89      TF  1722902917

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Northern Hemisphere: Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "output_data/NH_Temperature_vs_Latitude.png")

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Southern Hemisphere: Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "output_data/SH_Temperature_vs_Latitude.png")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere: Temperature vs. Latitude
# The linear regression plot for the Northern Hemisphere shows a negative correlation between latitude and maximum temperature. As the latitude increases, the maximum temperature decreases. This is expected because locations closer to the equator tend to be warmer.
#
# Southern Hemisphere: Temperature vs. Latitude
# The linear regression plot for the Southern Hemisphere also shows a negative correlation between latitude and maximum temperature. As the latitude decreases (moving closer to the South Pole), the maximum temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Northern Hemisphere: Humidity vs. Latitude", "Latitude", "Humidity (%)", "output_data/NH_Humidity_vs_Latitude.png")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Southern Hemisphere: Humidity vs. Latitude", "Latitude", "Humidity (%)", "output_data/SH_Humidity_vs_Latitude.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Hemisphere: Humidity vs. Latitude
# The linear regression plot for the Northern Hemisphere shows a weak positive correlation between latitude and humidity. As the latitude increases, the humidity slightly increases. This relationship might not be very strong.
#
# Southern Hemisphere: Humidity vs. Latitude
# The linear regression plot for the Southern Hemisphere shows a weak negative correlation between latitude and humidity. As the latitude decreases, the humidity slightly decreases. Similar to the Northern Hemisphere, this relationship might not be very strong.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Northern Hemisphere: Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "output_data/NH_Cloudiness_vs_Latitude.png")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Southern Hemisphere: Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "output_data/SH_Cloudiness_vs_Latitude.png")

# %% [markdown]
# **Discussion about the linear relationship:** Northern Hemisphere: Cloudiness vs. Latitude
# The linear regression plot for the Northern Hemisphere shows a weak positive correlation between latitude and cloudiness. As the latitude increases, the cloudiness slightly increases.
#
# Southern Hemisphere: Cloudiness vs. Latitude
# The linear regression plot for the Southern Hemisphere shows a weak negative correlation between latitude and cloudiness. As the latitude decreases, the cloudiness slightly decreases.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Northern Hemisphere: Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "output_data/NH_WindSpeed_vs_Latitude.png")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Southern Hemisphere: Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "output_data/SH_WindSpeed_vs_Latitude.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Hemisphere: Wind Speed vs. Latitude
# The linear regression plot for the Northern Hemisphere shows a weak positive correlation between latitude and wind speed. As the latitude increases, the wind speed slightly increases.
#
# Southern Hemisphere: Wind Speed vs. Latitude
# The linear regression plot for the Southern Hemisphere shows a weak positive correlation between latitude and wind speed. As the latitude decreases, the wind speed slightly increases.
